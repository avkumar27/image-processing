# %%
from __future__ import print_function, division

import os
import numpy as np
import random

import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import torch.optim as optim
import torchvision
from torchvision import datasets, models, transforms
from torch.optim import lr_scheduler
import pandas as pd
import matplotlib.pyplot as plt

import time
import copy
import shutil
import re
import PIL
#Mounting Google drive for Colab execution

from google.colab import drive
drive.mount('/content/drive')

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

your_module = drive.CreateFile({'id':'1dBH4qAfLeP5AUbIlLZunJqcBzQ2BOUFF'})
your_module.GetContentFile('util.py')

from util import plot_confusion_matrix

torch.manual_seed(0)
# Define train and test directories
base_dir = '/content/drive/My Drive/dataset/places/places/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Pre-processing the dataset
# Normalize the images
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# Resize the images
resize = transforms.Resize((224,224))

transforms = {
'train': transforms.Compose([
                             transforms.RandomResizedCrop(224),
                             transforms.RandomHorizontalFlip(),
                             transforms.ToTensor(),
                             normalize
                             ]), 
'test': transforms.Compose([
                            resize,
                            transforms.ToTensor(),
                            normalize]),
}

# Dataset augmentation is not performed on the training images therefore the transform can be common

# Normalize the test set same as training set No need to perform augmentation
#transform_test = transforms.Compose([
#    resize,
#    transforms.ToTensor(),
#    normalize,
#])

# %%
# Applying the transforms to the datasets
# trainset = datasets.ImageFolder( os.path.join( base_dir, 'train') , transform_images)
# trainloader = torch.utils.data.DataLoader( trainset , batch_size = 4, shuffle = True, num_workers = 4)
# The shuffle is set to true for the taining images
# testset = datasets.ImageFolder( os.path.join( base_dir, 'test') , transform_images)
# testloader = torch.utils.data.DataLoader( testset , batch_size = 4, shuffle = True, num_workers = 4)

# Use the image folder function to create datasets
dataset = { x: datasets.ImageFolder( os.path.join( base_dir, x ), transforms[x] )for x in ['train', 'test']}

dataloader = { x: torch.utils.data.DataLoader( dataset[x], batch_size = 4, shuffle = True, num_workers = 4) for x in ['train', 'test']}

# Defining the classes
dataset_sizes = { x: len(dataset[x]) for x in ['train', 'test']}
class_names = dataset['train'].classes


print(class_names)

# Number of classes in the dataset
num_classes = 9

# Number of epochs to train for
# num_epochs = 2
# Out:
# ['abbey', 'airport_terminal', 'alley', 'amphitheater', 'amusement_park', 'aquarium', 'aqueduct', 'arch', 'art_gallery']

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
alexnet = torchvision.models.alexnet(pretrained = True)

#for name, child in alexnet.named_children():
#  print(child)
#  print(name)

alexnet.classifier[6] = nn.Linear(4096,num_classes)
input_size = 224

model = alexnet.to(device)
print(model)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=9, bias=True)
#   )
# )

# %%
criterion = nn.CrossEntropyLoss()
criterion = criterion.to(device)

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model.parameters(), lr=0.001, momentum=0.6)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=4, gamma=0.5)

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs):
    since = time.time()
    flag = 0
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'test']:
            if phase == 'train':
                if flag == 1:
                  scheduler.step()
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            current_loss = 0.0
            current_corrects = 0

            # Here's where the training happens
            print('Iterating through data...')

            for inputs, labels in dataloader[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # We need to zero the gradients, don't forget it
                optimizer.zero_grad()
                flag = 1
                # Time to carry out the forward training pass
                # We only need to log the loss stats if we are in training phase
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # We want variables to hold the loss statistics
                current_loss += loss.item() * inputs.size(0)
                current_corrects += torch.sum(preds == labels.data)

            epoch_loss = current_loss / dataset_sizes[phase]
            epoch_acc = current_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # Make a copy of the model if the accuracy on the validation set has improved
            if phase == 'test' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_since = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_since // 60, time_since % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # Now we'll load in the best model weights and return it
    model.load_state_dict(best_model_wts)
    return model

# %%
def predict_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_handeled = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloader['test']):
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_handeled += 1
                ax = plt.subplot(num_images//2, 2, images_handeled)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_handeled == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
base_model = train_model(model, criterion, optimizer_ft, exp_lr_scheduler, 25)
# Out:
# Epoch 0/24
# ----------
# Iterating through data...
# train Loss: 1.4027 Acc: 0.5166
# Iterating through data...
# test Loss: 0.9413 Acc: 0.6894
#
# Epoch 1/24
# ----------
# Iterating through data...
# train Loss: 1.0688 Acc: 0.6454
# Iterating through data...
# test Loss: 0.9260 Acc: 0.6757
#
# Epoch 2/24
# ----------
# Iterating through data...
# train Loss: 0.9164 Acc: 0.6884
# Iterating through data...
# test Loss: 0.9310 Acc: 0.7084
#
# Epoch 3/24
# ----------
# Iterating through data...
# train Loss: 0.8272 Acc: 0.7050
# Iterating through data...
# test Loss: 1.0949 Acc: 0.6267
#
# Epoch 4/24
# ----------
# Iterating through data...
# train Loss: 0.6507 Acc: 0.7659
# Iterating through data...
# test Loss: 0.8880 Acc: 0.7248
#
# Epoch 5/24
# ----------
# Iterating through data...
# train Loss: 0.5763 Acc: 0.8130
# Iterating through data...
# test Loss: 0.9411 Acc: 0.7221
#
# Epoch 6/24
# ----------
# Iterating through data...
# train Loss: 0.6201 Acc: 0.7832
# Iterating through data...
# test Loss: 0.9352 Acc: 0.7248
#
# Epoch 7/24
# ----------
# Iterating through data...
# train Loss: 0.5222 Acc: 0.8248
# Iterating through data...
# test Loss: 0.9230 Acc: 0.7057
#
# Epoch 8/24
# ----------
# Iterating through data...
# train Loss: 0.4901 Acc: 0.8366
# Iterating through data...
# test Loss: 0.8852 Acc: 0.7330
#
# Epoch 9/24
# ----------
# Iterating through data...
# train Loss: 0.4375 Acc: 0.8483
# Iterating through data...
# test Loss: 0.8924 Acc: 0.7384
#
# Epoch 10/24
# ----------
# Iterating through data...
# train Loss: 0.4444 Acc: 0.8456
# Iterating through data...
# test Loss: 0.8700 Acc: 0.7493
#
# Epoch 11/24
# ----------
# Iterating through data...
# train Loss: 0.4049 Acc: 0.8663
# Iterating through data...
# test Loss: 0.9328 Acc: 0.7302
#
# Epoch 12/24
# ----------
# Iterating through data...
# train Loss: 0.3702 Acc: 0.8733
# Iterating through data...
# test Loss: 0.9147 Acc: 0.7493
#
# Epoch 13/24
# ----------
# Iterating through data...
# train Loss: 0.3693 Acc: 0.8802
# Iterating through data...
# test Loss: 0.9554 Acc: 0.7302
#
# Epoch 14/24
# ----------
# Iterating through data...
# train Loss: 0.3331 Acc: 0.8906
# Iterating through data...
# test Loss: 0.9458 Acc: 0.7493
#
# Epoch 15/24
# ----------
# Iterating through data...
# train Loss: 0.3336 Acc: 0.8892
# Iterating through data...
# test Loss: 0.9691 Acc: 0.7493
#
# Epoch 16/24
# ----------
# Iterating through data...
# train Loss: 0.3239 Acc: 0.8878
# Iterating through data...
# test Loss: 0.9417 Acc: 0.7657
#
# Epoch 17/24
# ----------
# Iterating through data...
# train Loss: 0.3287 Acc: 0.8947
# Iterating through data...
# test Loss: 0.9732 Acc: 0.7575
#
# Epoch 18/24
# ----------
# Iterating through data...
# train Loss: 0.3128 Acc: 0.8906
# Iterating through data...
# test Loss: 0.9555 Acc: 0.7520
#
# Epoch 19/24
# ----------
# Iterating through data...
# train Loss: 0.3176 Acc: 0.8934
# Iterating through data...
# test Loss: 0.9677 Acc: 0.7439
#
# Epoch 20/24
# ----------
# Iterating through data...
# train Loss: 0.3147 Acc: 0.9003
# Iterating through data...
# test Loss: 0.9662 Acc: 0.7439
#
# Epoch 21/24
# ----------
# Iterating through data...
# train Loss: 0.3255 Acc: 0.8899
# Iterating through data...
# test Loss: 0.9558 Acc: 0.7520
#
# Epoch 22/24
# ----------
# Iterating through data...
# train Loss: 0.3072 Acc: 0.8934
# Iterating through data...
# test Loss: 0.9790 Acc: 0.7466
#
# Epoch 23/24
# ----------
# Iterating through data...
# train Loss: 0.3407 Acc: 0.8878
# Iterating through data...
# test Loss: 0.9874 Acc: 0.7439
#
# Epoch 24/24
# ----------
# Iterating through data...
# train Loss: 0.2932 Acc: 0.8975
# Iterating through data...
# test Loss: 0.9769 Acc: 0.7493
#
# Training complete in 7m 19s
# Best val Acc: 0.765668
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-e49a2958c10f> in <module>()
#       1 base_model = train_model(model, criterion, optimizer_ft, exp_lr_scheduler, 25)
# ----> 2 predict_model(base_model)
#       3 plt.show()
#
# <ipython-input-28-513b6c8452a9> in predict_model(model, num_images)
#      17                 ax.axis('off')
#      18                 ax.set_title('predicted: {}'.format(class_names[preds[j]]))
# ---> 19                 imshow(inputs.cpu().data[j])
#      20
#      21                 if images_handeled == num_images:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2681         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2682         resample=resample, url=url, **({"data": data} if data is not
# -> 2683         None else {}), **kwargs)
#    2684     sci(__ret)
#    2685     return __ret
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     367                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     368                 f"should be pass as keyword, not positionally.")
# --> 369         return func(*args, **kwargs)
#     370
#     371     return wrapper
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     367                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     368                 f"should be pass as keyword, not positionally.")
# --> 369         return func(*args, **kwargs)
#     370
#     371     return wrapper
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5669                               resample=resample, **kwargs)
#    5670
# -> 5671         im.set_data(X)
#    5672         im.set_alpha(alpha)
#    5673         if im.get_clip_path() is None:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/image.py in set_data(self, A)
#     688                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
#     689             raise TypeError("Invalid shape {} for image data"
# --> 690                             .format(self._A.shape))
#     691
#     692         if self._A.ndim == 3:
#
# TypeError: Invalid shape (3, 224, 224) for image data

# %%
model_save_name = 'fineplusmodel.pt'
path = F"/content/drive/My Drive/{model_save_name}" 
torch.save(base_model.state_dict(), path)

# %%
confusion_matrix = torch.zeros(num_classes, num_classes)
with torch.no_grad():
    for i, (inputs, classes) in enumerate(dataloader['test']):
        inputs = inputs.to(device)
        classes = classes.to(device)
        # print(classes)
        outputs = base_model(inputs)
        _, preds = torch.max(outputs, 1)
        # print(preds)
        for t, p in zip(classes.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

print(confusion_matrix)
cm = confusion_matrix.cpu().numpy()
df = pd.DataFrame(cm, index = class_names, columns = class_names)
plt.savefig('conf_finetune.png')
df.style.background_gradient(cmap='Blues')
# Out:
# tensor([[29.,  0.,  4.,  3.,  0.,  0.,  2.,  2.,  0.],
#         [ 0., 36.,  0.,  0.,  0.,  1.,  0.,  0.,  4.],
#         [ 1.,  2., 36.,  0.,  0.,  0.,  0.,  2.,  0.],
#         [ 1.,  0.,  0., 30.,  4.,  0.,  2.,  3.,  1.],
#         [ 1.,  3.,  4.,  1., 30.,  0.,  1.,  0.,  0.],
#         [ 0.,  0.,  0.,  0.,  0., 41.,  0.,  0.,  0.],
#         [ 2.,  1.,  2.,  2.,  1.,  0., 28.,  5.,  0.],
#         [ 5.,  2.,  6.,  3.,  1.,  0.,  5., 18.,  1.],
#         [ 0.,  6.,  1.,  0.,  0.,  1.,  0.,  0., 33.]])
# <style  type="text/css" >
#     #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row0_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row0_col2 {
#             background-color:  #e1edf8;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row0_col3 {
#             background-color:  #e3eef9;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row0_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row0_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row0_col6 {
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row0_col7 {
#             background-color:  #e1edf8;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row0_col8 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row1_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row1_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row1_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row1_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row1_col5 {
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row1_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row1_col7 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row1_col8 {
#             background-color:  #dfebf7;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row2_col0 {
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row2_col1 {
#             background-color:  #ecf4fb;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row2_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row2_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row2_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row2_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row2_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row2_col7 {
#             background-color:  #e1edf8;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row2_col8 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row3_col0 {
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row3_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row3_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row3_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row3_col4 {
#             background-color:  #dceaf6;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row3_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row3_col6 {
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row3_col7 {
#             background-color:  #d6e6f4;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row3_col8 {
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row4_col0 {
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row4_col1 {
#             background-color:  #e7f0fa;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row4_col2 {
#             background-color:  #e1edf8;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row4_col3 {
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row4_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row4_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row4_col6 {
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row4_col7 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row4_col8 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row5_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row5_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row5_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row5_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row5_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row5_col5 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row5_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row5_col7 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row5_col8 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row6_col0 {
#             background-color:  #eaf2fb;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row6_col1 {
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row6_col2 {
#             background-color:  #ecf4fb;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row6_col3 {
#             background-color:  #eaf2fb;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row6_col4 {
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }    #T_7cabe3a2_1267_11ea_846b_0242ac1c0002row6_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
